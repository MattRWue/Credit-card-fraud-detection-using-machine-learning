# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Besitzer\Downloads\Credit Card Fraud Detection Datensatz\creditcard_2023.csv')

# %%
df.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486122  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %% [markdown]
# EDA:

# %%
classes = df['Class'].value_counts()
classes
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
normal_share = (classes[0] / classes.sum()) * 100
fraud_share = (classes[1] / classes.sum()) * 100
print(normal_share)
print(fraud_share)
# Out:
# 50.0
# 50.0

# %%
ax = classes.plot(kind='bar', figsize=(8, 8), tick_label=["Non-Fraudulent", "Fraudulent"], color=["green", "red"])

plt.xticks(ticks=[0, 1], labels=["Non-Fraudulent", "Fraudulent"])

plt.text(x=-0.2, y= classes[0] +3000, s=f'{classes[0]} ({normal_share}%)', size=12)
plt.text(x=0.8, y=classes[1] + 3000, s=f'{classes[1]} ({fraud_share}%)', size=12)
plt.savefig("fraudulent_vs_nonfraudulent.png", bbox_inches='tight')
plt.show()

# %%
df_no_id = df.drop(columns=['id'])
corr_matrix = df_no_id.corr().round(2)
plt.figure(figsize=(20, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.savefig("correlation_heatmap.png", bbox_inches='tight', dpi=300) 
plt.show()

# %%
#id and Class are exclude since they are not features, so only features V1-V28 and Amount should be plotted
exclude_columns = ["id", "Class"]
columns_to_plot = [col for col in df.columns if col not in exclude_columns]

fig, axes = plt.subplots(6, 5, figsize=(14, 16)) 
axes = axes.flatten()
for i, col in enumerate(columns_to_plot):
    ax = axes[i]
    
    sns.kdeplot(df[df['Class'] == 0][col], fill=True, color="green", label="Non-Fraudulent", alpha=0.5, ax=ax)
    sns.kdeplot(df[df['Class'] == 1][col], fill=True, color="red", label="Fraudulent", alpha=0.5, ax=ax)
    
    ax.set_xlabel(ax.get_xlabel(), fontsize=10)
    ax.set_ylabel(ax.get_ylabel(), fontsize=5)
    ax.tick_params(axis='both', which='major', labelsize=8)

    ax.legend(fontsize=6, loc='lower right')


plt.subplots_adjust(wspace=0.2, hspace=0.2)
plt.tight_layout()  
plt.savefig('density_plots.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Data Preprocessing Steps

# %%
df.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %% [markdown]
# Data Quality Check

# %%
print(f"Number of empty rows: {len(df[df.isnull().any(axis=1)])}")
print(f"Number of duplicate rows: {len(df[df.duplicated()])}")
print(f"Missing values per column:\n{df.isnull().sum()}")
# Out:
# Number of empty rows: 0
# Number of duplicate rows: 0
# Missing values per column:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Drop "id"

# %%
df = df.drop(columns=["id"])

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17  7.997245e-18
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00 -9.952786e+00
# 25%   -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01 -2.934955e-01
# 50%   -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02  8.108788e-02
# 75%    8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01  4.397368e-01
# max    2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00  4.271689e+01
#
#                  V6            V7            V8            V9           V10  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17  1.991314e-16
# ...

# %% [markdown]
# Standardize "Amount" column

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df["Amount"] = scaler.fit_transform(df[["Amount"]])

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17  7.997245e-18
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00 -9.952786e+00
# 25%   -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01 -2.934955e-01
# 50%   -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02  8.108788e-02
# 75%    8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01  4.397368e-01
# max    2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00  4.271689e+01
#
#                  V6            V7            V8            V9           V10  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17  1.991314e-16
# ...

# %% [markdown]
# Train-Test-Split:

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=["Class"]) 
y = df["Class"]  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Feature Selection with Lasso

# %%
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

lasso = Lasso(random_state=42)  
alphaparameter = {"alpha":  np.arange(0.01, 1.01, 0.01)}

grid_search = GridSearchCV(
    estimator=lasso,
    param_grid=alphaparameter,
    scoring='neg_mean_squared_error',  
    cv=5,          
)

grid_search.fit(X_train, y_train)
print("Best alpha = ", grid_search.best_params_)
coefficients = grid_search.best_estimator_.coef_
#Features with non-zero coefficients are important 
relevant_features = np.where(coefficients != 0)[0]
print("Selected Features:", X_train.columns[relevant_features])
#Features with coefficients reduced to zero are not important
not_relevant_features = np.where(coefficients == 0)[0]
print("Not-relevant Features:", X_train.columns[not_relevant_features])
# Out:
# Best alpha =  {'alpha': np.float64(0.01)}
# Selected Features: Index(['V1', 'V3', 'V4', 'V5', 'V7', 'V8', 'V10', 'V11', 'V12', 'V13', 'V14',
#        'V17', 'V18', 'V19', 'V23', 'V26', 'V28'],
#       dtype='object')
# Not-relevant Features: Index(['V2', 'V6', 'V9', 'V15', 'V16', 'V20', 'V21', 'V22', 'V24', 'V25',
#        'V27', 'Amount'],
#       dtype='object')

# %% [markdown]
# Coefficient Values:

# %%
feature_coefficients = pd.DataFrame({
    "Feature": X_train.columns,
    "Coefficient": coefficients
})
feature_coefficients.head(30)
# Out:
#    Feature  Coefficient
# 0       V1    -0.024739
# 1       V2    -0.000000
# 2       V3    -0.055139
# 3       V4     0.099996
# 4       V5     0.014934
# 5       V6     0.000000
# 6       V7     0.010115
# 7       V8    -0.013466
# 8       V9     0.000000
# 9      V10    -0.001266
# 10     V11     0.043073
# 11     V12    -0.106763
# 12     V13    -0.011055
# 13     V14    -0.184483
# 14     V15     0.000000
# 15     V16    -0.000000
# 16     V17     0.020398
# 17     V18     0.008512
# 18     V19    -0.000651
# 19     V20     0.000000
# 20     V21     0.000000
# 21     V22     0.000000
# 22     V23    -0.001573
# 23     V24    -0.000000
# 24     V25     0.000000
# 25     V26    -0.013924
# 26     V27    -0.000000
# 27     V28     0.009905
# 28  Amount     0.000000

# %% [markdown]
# Feature Selection Plot:

# %%
feature_names = X_train.columns
plt.figure(figsize=(12, 6))
plt.plot(feature_names, coefficients, marker=".", color="blue", linewidth=2, markersize=10)
plt.axhline(0, color='red', linewidth=1) 
plt.xlabel("Features")
plt.ylabel("Coefficient Values")
plt.title("Feature Coefficients from Lasso Regression")
plt.tight_layout()
plt.savefig("lasso_coefficients_plot.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Hyperparameter-tuning:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
relevant_features_with_names = X_train.columns[relevant_features]
X_train_relevant = X_train[relevant_features_with_names]
X_test_relevant = X_test[relevant_features_with_names]

# %%
logistic_params = {
    "C": [0.1, 1, 10, 100, 1000],
    "penalty": ["l2"],
    "solver": ["lbfgs", 'saga', "liblinear", 'sag']
}

logistic_model = LogisticRegression(random_state=42, max_iter=1000)
logistic_search = GridSearchCV(
    estimator=logistic_model,
    param_grid=logistic_params,
    scoring="f1", 
    cv=5,
    n_jobs=-1 
)

logistic_search.fit(X_train_relevant, y_train)
print("Best parameters for Logistic Regression:", logistic_search.best_params_)
# Out:
# Best parameters for Logistic Regression: {'C': 1000, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
rf_params = {
    "n_estimators": [100, 200, 300],
    "max_depth": [10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

rf_model = RandomForestClassifier(random_state=42)
rf_search = GridSearchCV(
    estimator=rf_model,
    param_grid=rf_params,
    scoring="f1",
    cv=5,
    verbose=3,
    n_jobs=-1 
)

rf_search.fit(X_train_relevant, y_train)
print("Best parameters for Random Forest:", rf_search.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best parameters for Random Forest: {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}

# %%
knn_params = {
    "n_neighbors": [1, 3, 5, 7, 9, 11],
    "metric": ["euclidean"]
}

knn_model = KNeighborsClassifier()
knn_search = GridSearchCV(
    estimator=knn_model,
    param_grid=knn_params,
    scoring="f1",
    cv=5,
    verbose=3,
    n_jobs=-1 
)

knn_search.fit(X_train_relevant, y_train)
print("Best parameters for KNN:", knn_search.best_params_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best parameters for KNN: {'metric': 'euclidean', 'n_neighbors': 1}
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
dt_params = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 7, 10],
    'min_samples_split': [2, 5, 10, 50, 100],
    'min_samples_leaf': [2, 5, 10, 50, 100]
}

dt_model = DecisionTreeClassifier(random_state=42)
dt_search = GridSearchCV(
    estimator=dt_model,
    param_grid=dt_params,
    scoring='f1',
    cv=5,
    verbose=3,
    n_jobs=-1 
)

dt_search.fit(X_train_relevant, y_train)
print("Best parameters for Decision Tree:", dt_search.best_params_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Best parameters for Decision Tree: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %% [markdown]
# Final Model Training:

# %%
# ** was used to unpack the best parameters from the GridSearchCV process into the model
final_logistic_model = LogisticRegression(**logistic_search.best_params_, random_state=42, max_iter=1000)
final_rf_model = RandomForestClassifier(**rf_search.best_params_, random_state=42)
final_knn_model = KNeighborsClassifier(**knn_search.best_params_)
final_dt_model = DecisionTreeClassifier(**dt_search.best_params_, random_state=42)

final_logistic_model.fit(X_train_relevant, y_train)
final_rf_model.fit(X_train_relevant, y_train)
final_knn_model.fit(X_train_relevant, y_train)
final_dt_model.fit(X_train_relevant, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=2, random_state=42)

# %% [markdown]
# Model Evaluation:

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
#def evaluate_model() was used for evaluating every machine learning models
def evaluate_model(model, X_test_relevant, y_test):
    y_pred = model.predict(X_test_relevant)
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print(f"Accuracy: {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall: {rec:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print("Confusion Matrix:")
    print(cm)
    return acc, prec, rec, f1, cm


print("Logistic Regression:")
evaluate_model(final_logistic_model, X_test_relevant, y_test)

print("\nRandom Forest:")
evaluate_model(final_rf_model, X_test_relevant, y_test)

print("\nKNN:")
evaluate_model(final_knn_model, X_test_relevant, y_test)

print("\nDecision Tree:")
evaluate_model(final_dt_model, X_test_relevant, y_test)
# Out:
# Logistic Regression:
# Accuracy: 0.9641
# Precision: 0.9799
# Recall: 0.9478
# F1 Score: 0.9636
# Confusion Matrix:
# [[83484  1665]
#  [ 4460 80980]]
#
# Random Forest:
# Accuracy: 0.9998
# Precision: 0.9997
# Recall: 1.0000
# F1 Score: 0.9998
# Confusion Matrix:
# [[85123    26]
#  [    0 85440]]
#
# KNN:
# Accuracy: 0.9996
# Precision: 0.9991
# Recall: 1.0000
# F1 Score: 0.9996
# Confusion Matrix:
# [[85074    75]
#  [    0 85440]]
#
# Decision Tree:
# Accuracy: 0.9842
# Precision: 0.9836
# Recall: 0.9848
# F1 Score: 0.9842
# Confusion Matrix:
# [[83750  1399]
#  [ 1296 84144]]
# (0.9842017949574708,
#  np.float64(0.9836456518943689),
#  np.float64(0.9848314606741573),
#  np.float64(0.9842381991192107),
#  array([[83750,  1399],
#         [ 1296, 84144]]))

# %%
confusion_matrix_logistic_regression = np.array([[83484, 1665],
                              [4460, 80980]])


classes2 = ['Legitimate (0)', 'Fraud (1)']

# Confusion Matrix plotten
plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix_logistic_regression, annot=True,fmt='d', cmap='Blues', xticklabels=classes2, yticklabels=classes2, annot_kws={"size": 14})

plt.title('Confusion Matrix Logistic Regression', fontsize=16)
plt.xlabel('Predicted',fontsize=14)
plt.ylabel('Actual',fontsize=14)

plt.tight_layout()
plt.savefig('confusion_matrix_logistic_regression.png', dpi=300)
plt.show()

# %%
confusion_matrix_random_forest = np.array([[85123, 26],
                              [0, 85440]])



plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix_random_forest, annot=True,fmt='d', cmap='Blues', xticklabels=classes2, yticklabels=classes2, annot_kws={"size": 14})

plt.title('Confusion Matrix Random Forest', fontsize=16)
plt.xlabel('Predicted',fontsize=14)
plt.ylabel('Actual',fontsize=14)

plt.tight_layout()
plt.savefig('confusion_matrix_random_forest.png', dpi=300)
plt.show()

# %%
confusion_matrix_KNN = np.array([[85074, 75],
                              [0, 85440]])


plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix_KNN, annot=True,fmt='d', cmap='Blues', xticklabels=classes2, yticklabels=classes2, annot_kws={"size": 14})

plt.title("Confusion Matrix KNN", fontsize=16)
plt.xlabel('Predicted',fontsize=14)
plt.ylabel('Actual',fontsize=14)

plt.tight_layout()
plt.savefig("confusion_matrix_knn.png", dpi=300)
plt.show()

# %%
confusion_matrix_decision_tree = np.array([[83750, 1399],
                              [1296, 84144]])


plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix_decision_tree, annot=True,fmt="d", cmap="Blues", xticklabels=classes2, yticklabels=classes2, annot_kws={"size": 14})

plt.title("Confusion Matrix Decision Tree", fontsize=16)
plt.xlabel("Predicted",fontsize=14)
plt.ylabel("Actual",fontsize=14)

plt.tight_layout()
plt.savefig("confusion_matrix_decision_tree.png", dpi=300)
plt.show()

# %%
models1 = ["Logistic Regression", "Random Forest", "KNN", "Decision Tree"]
accuracy1 = [0.9641, 0.9998, 0.9996, 0.9842]
precision1 = [0.9799, 0.9997, 0.9991, 0.9836]
recall1 = [0.9478, 1.0000, 1.0000, 0.9848]
f1_score1 = [0.9636, 0.9998, 0.9996, 0.9842]
x = np.arange(len(models1))


plt.figure(figsize=(10, 6))
plt.bar(x - 0.3, accuracy1, 0.2, label="Accuracy", color="lightblue")
plt.bar(x - 0.1, precision1, 0.2, label="Precision", color="coral")
plt.bar(x + 0.1, recall1, 0.2, label="Recall", color="limegreen")
plt.bar(x + 0.3, f1_score1, 0.2, label="F1 Score", color="orchid")

plt.xlabel("Models", fontsize=12)
plt.ylabel("Score", fontsize=12)
plt.title("Model Performance Comparison", fontsize=14)
plt.xticks(x, models1, rotation=15)
plt.ylim(0.9, 1.01) 
plt.legend()
plt.savefig("model_performance_comparison.png", dpi=300)
plt.tight_layout()
plt.show()
