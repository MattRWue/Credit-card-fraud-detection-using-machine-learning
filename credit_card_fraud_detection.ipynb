# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Besitzer\Downloads\Credit Card Fraud Detection Datensatz\creditcard_2023.csv')

# %%
df.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
#         V26       V27       V28    Amount  Class
# 0 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.312895 -0.300258 -0.244718   2513.54      0
# 3 -0.515950 -0.165316  0.048424   5384.44      0
# 4  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
#  20  V20     568630 non-null  float64
#  21  V21     568630 non-null  float64
#  22  V22     568630 non-null  float64
#  23  V23     568630 non-null  float64
#  24  V24     568630 non-null  float64
#  25  V25     568630 non-null  float64
#  26  V26     568630 non-null  float64
#  27  V27     568630 non-null  float64
#  28  V28     568630 non-null  float64
#  29  Amount  568630 non-null  float64
#  30  Class   568630 non-null  int64
# dtypes: float64(29), int64(2)
# memory usage: 134.5 MB

# %%
df.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486122  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -9.952786e+00 -2.111111e+01 -4.351839e+00 -1.075634e+01 -3.751919e+00
# 25%   -2.934955e-01 -4.458712e-01 -2.835329e-01 -1.922572e-01 -5.687446e-01
# 50%    8.108788e-02  7.871758e-02  2.333659e-01 -1.145242e-01  9.252647e-02
# 75%    4.397368e-01  4.977881e-01  5.259548e-01  4.729905e-02  5.592621e-01
# max    4.271689e+01  2.616840e+01  2.178730e+02  5.958040e+00  2.027006e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   ...  4.758361e-17  3.948640e-18  6.194741e-18 -2.799036e-18
# std    ...  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min    ... -1.938252e+01 -7.734798e+00 -3.029545e+01 -4.067968e+00
# 25%    ... -1.664408e-01 -4.904892e-01 -2.376289e-01 -6.515801e-01
# 50%    ... -3.743065e-02 -2.732881e-02 -5.968903e-02  1.590123e-02
# 75%    ...  1.479787e-01  4.638817e-01  1.557153e-01  7.007374e-01
# max    ...  8.087080e+00  1.263251e+01  3.170763e+01  1.296564e+01
#
#                 V25           V26           V27           V28         Amount  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  568630.000000
# mean  -3.178905e-17 -7.497417e-18 -3.598760e-17  2.609101e-17   12041.957635
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00    6919.644449
# min   -1.361263e+01 -8.226969e+00 -1.049863e+01 -3.903524e+01      50.010000
# 25%   -5.541485e-01 -6.318948e-01 -3.049607e-01 -2.318783e-01    6054.892500
# 50%   -8.193162e-03 -1.189208e-02 -1.729111e-01 -1.392973e-02   12030.150000
# 75%    5.500147e-01  6.728879e-01  3.340230e-01  4.095903e-01   18036.330000
# max    1.462151e+01  5.623285e+00  1.132311e+02  7.725594e+01   24039.930000
#
#           Class
# count  568630.0
# mean        0.5
# std         0.5
# min         0.0
# 25%         0.0
# 50%         0.5
# 75%         1.0
# max         1.0
#
# [8 rows x 31 columns]

# %%
classes = df['Class'].value_counts()
classes
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
normal_share = (classes[0] / classes.sum()) * 100
fraud_share = (classes[1] / classes.sum()) * 100
print(normal_share)
print(fraud_share)
# Out:
# 50.0
# 50.0

# %%
ax = classes.plot(kind='bar', figsize=(8, 8), tick_label=['Non-Fraudulent', 'Fraudulent'], color=['green', 'red'])

plt.xticks(ticks=[0, 1], labels=['Non-Fraudulent', 'Fraudulent'])

plt.text(x=-0.2, y= classes[0] +3000, s=f'{classes[0]} ({normal_share}%)', size=12)
plt.text(x=0.8, y=classes[1] + 3000, s=f'{classes[1]} ({fraud_share}%)', size=12)

# Show the plot
plt.savefig('fraudulent_vs_nonfraudulent.png', bbox_inches='tight')
plt.show()

# %%
df_no_id = df.drop(columns=['id'])
corr_matrix = df_no_id.corr().round(2)

# Set up the matplotlib figure
plt.figure(figsize=(20, 10))

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.savefig('correlation_heatmap.png', bbox_inches='tight', dpi=300) 


plt.show()

# %%
df_no_class = df.drop(columns=['id', 'Class'])

# Set up the number of rows and columns for the subplots
num_features = len(df_no_class.columns)
num_cols = 5  # Number of columns per row
num_rows = (num_features // num_cols) + (num_features % num_cols > 0) 
print(num_cols)
print(num_rows)
# Out:
# 5
# 6

# %%
"""fig, axes = plt.subplots(5, 6, figsize=(22, 7 * 6))  # Increased figure size
axes = axes.flatten()  # Flatten axes array to easily access them

# Loop through each feature to plot the density for Class 0 and Class 1
for i, col in enumerate(df_no_class.columns):
    ax = axes[i]
    
    # Plot non-fraudulent (Class 0) and fraudulent (Class 1) with larger labels and lines
    sns.kdeplot(df_no_class[df['Class'] == 0][col], fill=True, color="green", label="Non-Fraudulent", alpha=0.5, ax=ax)
    sns.kdeplot(df_no_class[df['Class'] == 1][col], fill=True, color="red", label="Fraudulent", alpha=0.5, ax=ax)
    
    # Title and labels with larger font size
    ax.set_title(f'{col}', fontsize=12, weight='bold')  # Make feature name bold and larger
    ax.set_xlabel(col, fontsize=10)
    ax.set_ylabel('Density', fontsize=10)
    
    # Increase legend font size and place it outside the plot
    ax.legend(fontsize=12, loc='upper right')

# Adjust layout to prevent overlapping labels and ensure a clean output
plt.tight_layout()
plt.savefig('density_plots.png', dpi=300, bbox_inches='tight')
plt.show()"""
# Out:
# 'fig, axes = plt.subplots(5, 6, figsize=(22, 7 * 6))  # Increased figure size\naxes = axes.flatten()  # Flatten axes array to easily access them\n\n# Loop through each feature to plot the density for Class 0 and Class 1\nfor i, col in enumerate(df_no_class.columns):\n    ax = axes[i]\n    \n    # Plot non-fraudulent (Class 0) and fraudulent (Class 1) with larger labels and lines\n    sns.kdeplot(df_no_class[df[\'Class\'] == 0][col], fill=True, color="green", label="Non-Fraudulent", alpha=0.5, ax=ax)\n    sns.kdeplot(df_no_class[df[\'Class\'] == 1][col], fill=True, color="red", label="Fraudulent", alpha=0.5, ax=ax)\n    \n    # Title and labels with larger font size\n    ax.set_title(f\'{col}\', fontsize=12, weight=\'bold\')  # Make feature name bold and larger\n    ax.set_xlabel(col, fontsize=10)\n    ax.set_ylabel(\'Density\', fontsize=10)\n    \n    # Increase legend font size and place it outside the plot\n    ax.legend(fontsize=12, loc=\'upper right\')\n\n# Adjust layout to prevent overlapping labels and ensure a clean output\nplt.tight_layout()\nplt.savefig(\'density_plots.png\', dpi=300, bbox_inches=\'tight\')\nplt.show()'

# %% [markdown]
# Data Preprocessing Steps

# %%
df.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
#         V26       V27       V28    Amount  Class
# 0 -0.434824 -0.081230 -0.151045  17982.10      0
# 1  0.296503 -0.248052 -0.064512   6531.37      0
# 2 -0.312895 -0.300258 -0.244718   2513.54      0
# 3 -0.515950 -0.165316  0.048424   5384.44      0
# 4  1.071126  0.023712  0.419117  14278.97      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
#  20  V20     568630 non-null  float64
#  21  V21     568630 non-null  float64
#  22  V22     568630 non-null  float64
#  23  V23     568630 non-null  float64
#  24  V24     568630 non-null  float64
#  25  V25     568630 non-null  float64
#  26  V26     568630 non-null  float64
#  27  V27     568630 non-null  float64
#  28  V28     568630 non-null  float64
#  29  Amount  568630 non-null  float64
#  30  Class   568630 non-null  int64
# dtypes: float64(29), int64(2)
# memory usage: 134.5 MB

# %% [markdown]
# Data Quality Check

# %%
print(f"Number of empty rows: {len(df[df.isnull().any(axis=1)])}")
print(f"Number of duplicate rows: {len(df[df.duplicated()])}")
print(f"Missing values per column:\n{df.isnull().sum()}")
# Out:
# Number of empty rows: 0
# Number of duplicate rows: 0
# Missing values per column:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Drop "id"

# %%
df = df.drop(columns=["id"])

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17  7.997245e-18
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00 -9.952786e+00
# 25%   -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01 -2.934955e-01
# 50%   -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02  8.108788e-02
# 75%    8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01  4.397368e-01
# max    2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00  4.271689e+01
#
#                  V6            V7            V8            V9           V10  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17  1.991314e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -2.111111e+01 -4.351839e+00 -1.075634e+01 -3.751919e+00 -3.163276e+00
# 25%   -4.458712e-01 -2.835329e-01 -1.922572e-01 -5.687446e-01 -5.901008e-01
# 50%    7.871758e-02  2.333659e-01 -1.145242e-01  9.252647e-02  2.626145e-01
# 75%    4.977881e-01  5.259548e-01  4.729905e-02  5.592621e-01  5.924603e-01
# max    2.616840e+01  2.178730e+02  5.958040e+00  2.027006e+01  3.172271e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   ...  4.758361e-17  3.948640e-18  6.194741e-18 -2.799036e-18
# std    ...  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min    ... -1.938252e+01 -7.734798e+00 -3.029545e+01 -4.067968e+00
# 25%    ... -1.664408e-01 -4.904892e-01 -2.376289e-01 -6.515801e-01
# 50%    ... -3.743065e-02 -2.732881e-02 -5.968903e-02  1.590123e-02
# 75%    ...  1.479787e-01  4.638817e-01  1.557153e-01  7.007374e-01
# max    ...  8.087080e+00  1.263251e+01  3.170763e+01  1.296564e+01
#
#                 V25           V26           V27           V28         Amount  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  568630.000000
# mean  -3.178905e-17 -7.497417e-18 -3.598760e-17  2.609101e-17   12041.957635
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00    6919.644449
# min   -1.361263e+01 -8.226969e+00 -1.049863e+01 -3.903524e+01      50.010000
# 25%   -5.541485e-01 -6.318948e-01 -3.049607e-01 -2.318783e-01    6054.892500
# 50%   -8.193162e-03 -1.189208e-02 -1.729111e-01 -1.392973e-02   12030.150000
# 75%    5.500147e-01  6.728879e-01  3.340230e-01  4.095903e-01   18036.330000
# max    1.462151e+01  5.623285e+00  1.132311e+02  7.725594e+01   24039.930000
#
#           Class
# count  568630.0
# mean        0.5
# std         0.5
# min         0.0
# 25%         0.0
# 50%         0.5
# 75%         1.0
# max         1.0
#
# [8 rows x 30 columns]

# %% [markdown]
# Standardize "Amount" column

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df["Amount"] = scaler.fit_transform(df[["Amount"]])

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17  7.997245e-18
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00 -9.952786e+00
# 25%   -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01 -2.934955e-01
# 50%   -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02  8.108788e-02
# 75%    8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01  4.397368e-01
# max    2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00  4.271689e+01
#
#                  V6            V7            V8            V9           V10  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17  1.991314e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -2.111111e+01 -4.351839e+00 -1.075634e+01 -3.751919e+00 -3.163276e+00
# 25%   -4.458712e-01 -2.835329e-01 -1.922572e-01 -5.687446e-01 -5.901008e-01
# 50%    7.871758e-02  2.333659e-01 -1.145242e-01  9.252647e-02  2.626145e-01
# 75%    4.977881e-01  5.259548e-01  4.729905e-02  5.592621e-01  5.924603e-01
# max    2.616840e+01  2.178730e+02  5.958040e+00  2.027006e+01  3.172271e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   ...  4.758361e-17  3.948640e-18  6.194741e-18 -2.799036e-18
# std    ...  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min    ... -1.938252e+01 -7.734798e+00 -3.029545e+01 -4.067968e+00
# 25%    ... -1.664408e-01 -4.904892e-01 -2.376289e-01 -6.515801e-01
# 50%    ... -3.743065e-02 -2.732881e-02 -5.968903e-02  1.590123e-02
# 75%    ...  1.479787e-01  4.638817e-01  1.557153e-01  7.007374e-01
# max    ...  8.087080e+00  1.263251e+01  3.170763e+01  1.296564e+01
#
#                 V25           V26           V27           V28        Amount  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -3.178905e-17 -7.497417e-18 -3.598760e-17  2.609101e-17 -4.021240e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.361263e+01 -8.226969e+00 -1.049863e+01 -3.903524e+01 -1.733031e+00
# 25%   -5.541485e-01 -6.318948e-01 -3.049607e-01 -2.318783e-01 -8.652280e-01
# 50%   -8.193162e-03 -1.189208e-02 -1.729111e-01 -1.392973e-02 -1.706395e-03
# 75%    5.500147e-01  6.728879e-01  3.340230e-01  4.095903e-01  8.662841e-01
# max    1.462151e+01  5.623285e+00  1.132311e+02  7.725594e+01  1.733902e+00
#
#           Class
# count  568630.0
# mean        0.5
# std         0.5
# min         0.0
# 25%         0.0
# 50%         0.5
# 75%         1.0
# max         1.0
#
# [8 rows x 30 columns]

# %% [markdown]
# Train-Test-Split:

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=["Class"]) 
y = df["Class"]  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Feature Selection with Lasso

# %%
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

lasso = Lasso(random_state=42)  
param_grid = {
    'alpha': np.arange(0.0001, 0.1, 0.001) 
}

grid_search = GridSearchCV(
    estimator=lasso,
    param_grid=param_grid,
    scoring='f1',  
    cv=5,          
)

grid_search.fit(X_train, y_train)
print("Best alpha = ", grid_search.best_params_)
coefficients = grid_search.best_estimator_.coef_
#Features with non-zero coefficients are important 
relevant_features = np.where(coefficients != 0)[0]
print("Selected Features:", X_train.columns[relevant_features])
#Features with coefficients reduced to zero are not important
not_relevant_features = np.where(coefficients == 0)[0]
print("Non-relevant Features:", X_train.columns[not_relevant_features])
# Out:
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
# ...
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 376, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1293, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1485, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1789, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 1561, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py", line 112, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
#
#   warnings.warn(
# c:\Users\Besitzer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# Best alpha =  {'alpha': np.float64(0.0001)}
# Selected Features: Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')
# Non-relevant Features: Index([], dtype='object')
